# %%
#cant program like this. Should have a class which is a constructor/destructor
#since we dont want these objects to persist after we are done with testing
#
import boto3

ec2 = boto3.resource('ec2')

# create VPC
vpc = ec2.create_vpc(CidrBlock='10.0.0.0/25')
vpc.create_tags(Tags=[{"Key": "Name", "Value": "lambda_vpc"}])

vpc.wait_until_available()

#create 2 public subnets

subnet1 = ec2.create_subnet(CidrBlock='10.0.0.0/28', VpcId=vpc.id)
subnet2 = ec2.create_subnet(CidrBlock='10.0.0.16/28', VpcId=vpc.id)
subnet1.create_tags(Tags=[{"Key": "Name", "Value": "public_one"}])
subnet1.wait_until_available()
subnet1.create_tags(Tags=[{"Key": "Name", "Value": "public_two"}])
subnet1.wait_until_available()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/xg/24wnv8p16mn4lssp8jqmvq6m0000gn/T/ipykernel_44182/3718731952.py in <module>
# ----> 1 import boto3
#       2
#       3 ec2 = boto3.resource('ec2')
#       4
#       5 # create VPC
#
# ModuleNotFoundError: No module named 'boto3'

# %%
import boto3

client = boto3.client('ec2')
print(client.describe_subnets())
print("----------------------")
print(client.describe_tags())
print("----------------------")
print(client.describe_vpcs())
print("----------------------")
print(client.describe_vpn_gateways())
print("----------------------")
#print(client.describe_tags())
#print(client.describe_tags())
# Out:
# {'Subnets': [], 'ResponseMetadata': {'RequestId': '66bbc7d6-598a-4917-8b33-d940456daef8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '66bbc7d6-598a-4917-8b33-d940456daef8', 'cache-control': 'no-cache, no-store', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-type': 'text/xml;charset=UTF-8', 'content-length': '221', 'date': 'Mon, 21 Feb 2022 16:49:59 GMT', 'server': 'AmazonEC2'}, 'RetryAttempts': 0}}
# ----------------------
# {'Tags': [{'Key': 'Name', 'ResourceId': 'vpc-069c67081318b793d', 'ResourceType': 'vpc', 'Value': 'lambda_vpc'}], 'ResponseMetadata': {'RequestId': 'f2cbad48-45aa-47df-94e0-33644a3891e4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'f2cbad48-45aa-47df-94e0-33644a3891e4', 'cache-control': 'no-cache, no-store', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-type': 'text/xml;charset=UTF-8', 'content-length': '426', 'date': 'Mon, 21 Feb 2022 16:49:59 GMT', 'server': 'AmazonEC2'}, 'RetryAttempts': 0}}
# ----------------------
# {'Vpcs': [{'CidrBlock': '10.0.0.0/25', 'DhcpOptionsId': 'dopt-2d788549', 'State': 'available', 'VpcId': 'vpc-069c67081318b793d', 'OwnerId': '669059827483', 'InstanceTenancy': 'default', 'CidrBlockAssociationSet': [{'AssociationId': 'vpc-cidr-assoc-084c6aee1b8f7dc1c', 'CidrBlock': '10.0.0.0/25', 'CidrBlockState': {'State': 'associated'}}], 'IsDefault': False, 'Tags': [{'Key': 'Name', 'Value': 'lambda_vpc'}]}, {'CidrBlock': '172.30.0.0/16', 'DhcpOptionsId': 'dopt-2d788549', 'State': 'available', 'VpcId': 'vpc-0dd4af04736c79917', 'OwnerId': '669059827483', 'InstanceTenancy': 'default', 'CidrBlockAssociationSet': [{'AssociationId': 'vpc-cidr-assoc-0d72d2c20a7384a44', 'CidrBlock': '172.30.0.0/16', 'CidrBlockState': {'State': 'associated'}}], 'IsDefault': False}], 'ResponseMetadata': {'RequestId': 'bb94e2c4-5a2b-49ea-bc58-d9c3955fbbe9', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'bb94e2c4-5a2b-49ea-bc58-d9c3955fbbe9', 'cache-control': 'no-cache, no-store', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-type': 'text/xml;charset=UTF-8', 'content-length': '1899', 'date': 'Mon, 21 Feb 2022 16:49:59 GMT', 'server': 'AmazonEC2'}, 'RetryAttempts': 0}}
# ----------------------
# {'VpnGateways': [], 'ResponseMetadata': {'RequestId': '83f3b380-aed0-4369-ad55-aebb522a1ceb', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '83f3b380-aed0-4369-ad55-aebb522a1ceb', 'cache-control': 'no-cache, no-store', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'content-type': 'text/xml;charset=UTF-8', 'content-length': '234', 'date': 'Mon, 21 Feb 2022 16:49:59 GMT', 'server': 'AmazonEC2'}, 'RetryAttempts': 0}}
# ----------------------

# %%
def foo():
    print("this is foo")


def executor():
    some_string = "foo()"
    eval(some_string)
executor()
# Out:
# this is foo

# %%
import boto3,inspect,sys
client = boto3.client('ec2')
what_am_i=inspect.getmembers(client)
type(what_am_i)
for x in what_am_i:
    print(type(x),len(x))
# Out:
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2
# <class 'tuple'> 2

# %%
import boto3,inspect,sys
client = boto3.client('ec2')
what_am_i=inspect.getmembers(client)
type(what_am_i)
for x in what_am_i:
    if len(x)!=2:
        raise ValueError

# %%
import boto3,inspect,sys
client = boto3.client('ec2')
what_am_i=inspect.getmembers(client)
type(what_am_i)
for x in what_am_i:
    assert(len(x)==2)

# %%
import boto3

client = boto3.client('ce')
client.get_cost_and_usage(TimePeriod={
        'Start': '2021-03-01',
        'End': '2022-02-21'
    },
    Granularity='MONTHLY',
    Metrics=[
        'UsageQuantity',
        'AmortizedCost' , 
        'BlendedCost' , 
        'NetAmortizedCost' , 
        'NetUnblendedCost' , 
        'NormalizedUsageAmount' , 
        'UnblendedCost' 
    ]
)
# Out:
# {'ResultsByTime': [{'TimePeriod': {'Start': '2021-03-01', 'End': '2021-04-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.0000555396', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-04-01', 'End': '2021-05-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.000055539', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-05-01', 'End': '2021-06-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.0000555396', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-06-01', 'End': '2021-07-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.000055539', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-07-01', 'End': '2021-08-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.0000555396', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-08-01', 'End': '2021-09-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.0000554293', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-09-01', 'End': '2021-10-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.000055539', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-10-01', 'End': '2021-11-01'},
#    'Total': {'AmortizedCost': {'Amount': '0.0000777', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0.0000777', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0.0000777', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0.0000777', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0.0000777', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '53.1694805956', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-11-01', 'End': '2021-12-01'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '0.000015921', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2021-12-01', 'End': '2022-01-01'},
#    'Total': {'AmortizedCost': {'Amount': '0.0035398985', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0.0035398985', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0.0035398985', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0.0035398985', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0.0035398985', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '751.3186589623', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2022-01-01', 'End': '2022-02-01'},
#    'Total': {'AmortizedCost': {'Amount': '0.0003586138', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0.0003586138', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0.0003586138', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0.0003586138', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0.0003586138', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '94.0211960626', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': False},
#   {'TimePeriod': {'Start': '2022-02-01', 'End': '2022-02-21'},
#    'Total': {'AmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'BlendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetAmortizedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NetUnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'NormalizedUsageAmount': {'Amount': '0', 'Unit': 'N/A'},
#     'UnblendedCost': {'Amount': '0', 'Unit': 'USD'},
#     'UsageQuantity': {'Amount': '19.1195416758', 'Unit': 'N/A'}},
#    'Groups': [],
#    'Estimated': True}],
#  'DimensionValueAttributes': [],
#  'ResponseMetadata': {'RequestId': 'b0dbad67-fedc-40f8-9770-1c18e2a3e2d3',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Mon, 21 Feb 2022 19:08:45 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '5335',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'b0dbad67-fedc-40f8-9770-1c18e2a3e2d3',
#    'cache-control': 'no-cache'},
#   'RetryAttempts': 0}}

# %%
import boto3

client = boto3.client('ce')
client.get_cost_and_usage_with_resources(TimePeriod={
        'Start': '2021-03-01',
        'End': '2022-02-21'
    },
    Granularity='MONTHLY',
    Metrics=[
        'UsageQuantity',
        'AmortizedCost' , 
        'BlendedCost' , 
        'NetAmortizedCost' , 
        'NetUnblendedCost' , 
        'NormalizedUsageAmount' , 
        'UnblendedCost' 
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# /var/folders/xg/24wnv8p16mn4lssp8jqmvq6m0000gn/T/ipykernel_55648/1251594071.py in <module>
#       2
#       3 client = boto3.client('ce')
# ----> 4 client.get_cost_and_usage_with_resources(TimePeriod={
#       5         'Start': '2021-03-01',
#       6         'End': '2022-02-21'
#
# ~/miniconda3/envs/visdom/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda3/envs/visdom/lib/python3.9/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     689             'auth_type': operation_model.auth_type,
#     690         }
# --> 691         request_dict = self._convert_to_request_dict(
#     692             api_params, operation_model, context=request_context)
#     693
#
# ~/miniconda3/envs/visdom/lib/python3.9/site-packages/botocore/client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     737         api_params = self._emit_api_params(
#     738             api_params, operation_model, context)
# --> 739         request_dict = self._serializer.serialize_to_request(
#     740             api_params, operation_model)
#     741         if not self._client_config.inject_host_prefix:
#
# ~/miniconda3/envs/visdom/lib/python3.9/site-packages/botocore/validate.py in serialize_to_request(self, parameters, operation_model)
#     358                                                     operation_model.input_shape)
#     359             if report.has_errors():
# --> 360                 raise ParamValidationError(report=report.generate_report())
#     361         return self._serializer.serialize_to_request(parameters,
#     362                                                      operation_model)
#
# ParamValidationError: Parameter validation failed:
# Missing required parameter in input: "Filter"
