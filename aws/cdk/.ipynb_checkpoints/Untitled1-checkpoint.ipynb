# %%
import os,sys,subprocess

class FindImports:
    def __init__(self):
        self.start_dir="/Users/dougchang/Downloads/aws-cli-develop"
    def find_files(self,start_dir):
        files_dirs = os.listdir(start_dir)
        for x in files_dirs:
            #print("x:",x,os.path.join(start_dir,x))
            #print("type:", os.path.join(start_dir,x))
            if(os.path.isdir(os.path.join(start_dir,x))):
                #print("new dir:",os.path.join(start_dir,x))
                self.find_files(os.path.join(start_dir,x))
            else:
                if x[-2:]=="py":
                    print("file:",x,os.path.join(start_dir,x))
                    here = os.path.join(start_dir,x)
                    cmd = "cat {} | grep import".format(here)
                    print("cmd:",cmd)
                    ps = subprocess.Popen(cmd,shell=True,stdout=subprocess.PIPE,stderr=subprocess.STDOUT)
                    output = ps.communicate()[0]
                    print("output:",output)
            #    sys.exit()
fi = FindImports()
fi.find_files(fi.start_dir)
# Out:
# file: test_errorhandler.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_errorhandler.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_errorhandler.py | grep import
# output: b'from awscli.testutils import mock, unittest\nfrom awscli import errorhandler\n'
# file: test_paramfile.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_paramfile.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_paramfile.py | grep import
# output: b'from awscli.compat import six\nfrom awscli.testutils import mock, unittest, FileCreator\nfrom awscli.testutils import skip_if_windows\nfrom awscli.paramfile import get_paramfile, ResourceLoadingError\nfrom awscli.paramfile import LOCAL_PREFIX_MAP, REMOTE_PREFIX_MAP\nfrom awscli.paramfile import register_uri_param_handler\nfrom botocore.session import Session\nfrom botocore.exceptions import ProfileNotFound\n'
# file: test_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_utils.py | grep import
# output: b'import signal\nimport platform\nimport subprocess\nimport os\nimport botocore.model\nfrom awscli.testutils import unittest, skip_if_windows, mock\nfrom awscli.utils import (\n'
# file: test_plugin.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_plugin.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/test_plugin.py | grep import
# output: b'import sys\nfrom awscli.testutils import mock, unittest\nfrom awscli import plugin\nfrom botocore import hooks\n'
# file: test_base36.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emrcontainers/test_base36.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emrcontainers/test_base36.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.emrcontainers.base36 import Base36\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emrcontainers/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emrcontainers/__init__.py | grep import
# output: b''
# file: test_update_assume_role_policy.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emrcontainers/test_update_assume_role_policy.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emrcontainers/test_update_assume_role_policy.py | grep import
# output: b'import copy\nimport json\nfrom awscli.testutils import BaseAWSCommandParamsTest, mock, unittest\nfrom awscli.customizations.emrcontainers.base36 import Base36\n    import TRUST_POLICY_STATEMENT_FORMAT, \\\n'
# file: test_generateprovisioningartifact.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_generateprovisioningartifact.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_generateprovisioningartifact.py | grep import
# output: b'from argparse import Namespace\nfrom awscli.customizations.servicecatalog import exceptions\n    import GenerateProvisioningArtifactCommand\nfrom awscli.testutils import unittest, mock, capture_output\nfrom botocore.compat import json\n'
# file: test_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_utils.py | grep import
# output: b'from awscli.customizations.servicecatalog import utils\nfrom awscli.testutils import unittest\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/__init__.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.testutils import mock\nfrom awscli.customizations.servicecatalog import \\\nfrom awscli.customizations.servicecatalog import inject_commands\n'
# file: test_generate.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_generate.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_generate.py | grep import
# output: b'from argparse import Namespace\nfrom awscli.customizations.servicecatalog import GenerateCommand\nfrom awscli.testutils import unittest\n'
# file: test_generateproduct.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_generateproduct.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/servicecatalog/test_generateproduct.py | grep import
# output: b'from argparse import Namespace\nfrom awscli.customizations.servicecatalog import exceptions\n    import GenerateProductCommand\nfrom awscli.testutils import unittest, mock, capture_output\nfrom botocore.compat import json\n'
# file: test_flatten.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_flatten.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_flatten.py | grep import
# output: b'from awscli.testutils import mock, unittest\nfrom awscli.arguments import CLIArgument\nfrom awscli.customizations import utils\nfrom awscli.customizations.flatten import FlattenedArgument, FlattenArguments\n'
# file: test_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_utils.py | grep import
# output: b'import io\nimport argparse\nfrom botocore.exceptions import ClientError\nfrom awscli.customizations import utils\nfrom awscli.testutils import mock\nfrom awscli.testutils import unittest\nfrom awscli.testutils import BaseAWSHelpOutputTest\n'
# file: test_sizeonly.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_sizeonly.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_sizeonly.py | grep import
# output: b'import datetime\nfrom awscli.customizations.s3.filegenerator import FileStat\nfrom awscli.customizations.s3.syncstrategy.sizeonly import SizeOnlySync\nfrom awscli.testutils import unittest\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/__init__.py | grep import
# output: b''
# file: test_register.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_register.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_register.py | grep import
# output: b'from awscli.customizations.s3.syncstrategy.register import \\\nfrom awscli.testutils import mock, unittest\n'
# file: test_delete.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_delete.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_delete.py | grep import
# output: b'import datetime\nfrom awscli.customizations.s3.filegenerator import FileStat\nfrom awscli.customizations.s3.syncstrategy.delete import DeleteSync\nfrom awscli.testutils import unittest\n'
# file: test_exacttimestamps.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_exacttimestamps.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_exacttimestamps.py | grep import
# output: b'import datetime\nfrom awscli.customizations.s3.filegenerator import FileStat\nfrom awscli.customizations.s3.syncstrategy.exacttimestamps import \\\nfrom awscli.testutils import unittest\n'
# file: test_base.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_base.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/syncstrategy/test_base.py | grep import
# output: b'import datetime\nfrom awscli.customizations.s3.filegenerator import FileStat\nfrom awscli.customizations.s3.syncstrategy.base import BaseSync, \\\nfrom awscli.testutils import mock, unittest\n'
# file: test_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_utils.py | grep import
# output: b'from awscli.testutils import mock, unittest, temporary_file\nimport argparse\nimport errno\nimport os\nimport tempfile\nimport shutil\nimport ntpath\nimport time\nimport datetime\nimport pytest\nfrom dateutil.tz import tzlocal\nfrom s3transfer.futures import TransferMeta, TransferFuture\nfrom s3transfer.compat import seekable\nfrom botocore.hooks import HierarchicalEmitter\nfrom awscli.compat import queue\nfrom awscli.compat import StringIO\nfrom awscli.testutils import FileCreator\nfrom awscli.customizations.s3.utils import (\nfrom awscli.customizations.s3.results import WarningResult\nfrom tests.unit.customizations.s3 import FakeTransferFuture\nfrom tests.unit.customizations.s3 import FakeTransferFutureMeta\nfrom tests.unit.customizations.s3 import FakeTransferFutureCallArgs\n'
# file: test_results.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_results.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_results.py | grep import
# output: b'from s3transfer.exceptions import CancelledError\nfrom s3transfer.exceptions import FatalError\nfrom awscli.testutils import unittest\nfrom awscli.testutils import mock\nfrom awscli.compat import queue\nfrom awscli.compat import StringIO\nfrom awscli.customizations.s3.results import ShutdownThreadRequest\nfrom awscli.customizations.s3.results import QueuedResult\nfrom awscli.customizations.s3.results import ProgressResult\nfrom awscli.customizations.s3.results import SuccessResult\nfrom awscli.customizations.s3.results import FailureResult\nfrom awscli.customizations.s3.results import ErrorResult\nfrom awscli.customizations.s3.results import CtrlCResult\nfrom awscli.customizations.s3.results import DryRunResult\nfrom awscli.customizations.s3.results import FinalTotalSubmissionsResult\nfrom awscli.customizations.s3.results import UploadResultSubscriber\nfrom awscli.customizations.s3.results import UploadStreamResultSubscriber\nfrom awscli.customizations.s3.results import DownloadResultSubscriber\nfrom awscli.customizations.s3.results import DownloadStreamResultSubscriber\nfrom awscli.customizations.s3.results import CopyResultSubscriber\nfrom awscli.customizations.s3.results import DeleteResultSubscriber\nfrom awscli.customizations.s3.results import ResultRecorder\nfrom awscli.customizations.s3.results import ResultPrinter\nfrom awscli.customizations.s3.results import OnlyShowErrorsResultPrinter\nfrom awscli.customizations.s3.results import NoProgressResultPrinter\nfrom awscli.customizations.s3.results import ResultProcessor\nfrom awscli.customizations.s3.results import CommandResultRecorder\nfrom awscli.customizations.s3.utils import relative_path\nfrom awscli.customizations.s3.utils import WarningResult\nfrom tests.unit.customizations.s3 import FakeTransferFuture\nfrom tests.unit.customizations.s3 import FakeTransferFutureMeta\nfrom tests.unit.customizations.s3 import FakeTransferFutureCallArgs\n        # NOTE: The actual values are not important for the purpose\n'
# file: test_transferconfig.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_transferconfig.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_transferconfig.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.s3 import transferconfig\nfrom awscli.compat import six\n'
# file: test_subcommands.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_subcommands.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_subcommands.py | grep import
# output: b'import argparse\nimport os\nimport sys\nimport botocore.session\nfrom awscli.customizations.s3.s3 import S3\nfrom awscli.customizations.s3.subcommands import CommandParameters, \\\nfrom awscli.customizations.s3.transferconfig import RuntimeConfig\nfrom awscli.customizations.s3.syncstrategy.base import \\\nfrom awscli.testutils import mock, unittest, BaseAWSHelpOutputTest, \\\nfrom tests.unit.customizations.s3 import make_loc_files, clean_loc_files\nfrom awscli.compat import StringIO\n'
# file: test_filegenerator.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_filegenerator.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_filegenerator.py | grep import
# output: b'import os\nimport platform\nfrom awscli.testutils import mock, unittest, FileCreator, BaseAWSCommandParamsTest\nfrom awscli.testutils import skip_if_windows\nimport stat\nimport tempfile\nimport shutil\nimport socket\nfrom botocore.exceptions import ClientError\nfrom awscli.compat import six\nfrom awscli.customizations.s3.filegenerator import FileGenerator, \\\nfrom awscli.customizations.s3.utils import get_file_stat, EPOCH_TIME\nfrom tests.unit.customizations.s3 import make_loc_files, clean_loc_files, \\\n'
# file: test_s3handler.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_s3handler.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_s3handler.py | grep import
# output: b'import os\nfrom s3transfer.manager import TransferManager\nfrom awscli.testutils import mock\nfrom awscli.testutils import unittest\nfrom awscli.testutils import FileCreator\nfrom awscli.compat import queue\nfrom awscli.customizations.s3.s3handler import S3TransferHandler\nfrom awscli.customizations.s3.s3handler import S3TransferHandlerFactory\nfrom awscli.customizations.s3.s3handler import UploadRequestSubmitter\nfrom awscli.customizations.s3.s3handler import DownloadRequestSubmitter\nfrom awscli.customizations.s3.s3handler import CopyRequestSubmitter\nfrom awscli.customizations.s3.s3handler import UploadStreamRequestSubmitter\nfrom awscli.customizations.s3.s3handler import DownloadStreamRequestSubmitter\nfrom awscli.customizations.s3.s3handler import DeleteRequestSubmitter\nfrom awscli.customizations.s3.s3handler import LocalDeleteRequestSubmitter\nfrom awscli.customizations.s3.fileinfo import FileInfo\nfrom awscli.customizations.s3.results import QueuedResult\nfrom awscli.customizations.s3.results import SuccessResult\nfrom awscli.customizations.s3.results import FailureResult\nfrom awscli.customizations.s3.results import UploadResultSubscriber\nfrom awscli.customizations.s3.results import DownloadResultSubscriber\nfrom awscli.customizations.s3.results import CopyResultSubscriber\nfrom awscli.customizations.s3.results import UploadStreamResultSubscriber\nfrom awscli.customizations.s3.results import DownloadStreamResultSubscriber\nfrom awscli.customizations.s3.results import DeleteResultSubscriber\nfrom awscli.customizations.s3.results import ResultRecorder\nfrom awscli.customizations.s3.results import ResultProcessor\nfrom awscli.customizations.s3.results import CommandResultRecorder\nfrom awscli.customizations.s3.results import DryRunResult\nfrom awscli.customizations.s3.utils import MAX_UPLOAD_SIZE\nfrom awscli.customizations.s3.utils import NonSeekableStream\nfrom awscli.customizations.s3.utils import StdoutBytesWriter\nfrom awscli.customizations.s3.utils import WarningResult\nfrom awscli.customizations.s3.utils import ProvideSizeSubscriber\nfrom awscli.customizations.s3.utils import ProvideUploadContentTypeSubscriber\nfrom awscli.customizations.s3.utils import ProvideCopyContentTypeSubscriber\nfrom awscli.customizations.s3.utils import ProvideLastModifiedTimeSubscriber\nfrom awscli.customizations.s3.utils import DirectoryCreatorSubscriber\nfrom awscli.customizations.s3.utils import DeleteSourceFileSubscriber\nfrom awscli.customizations.s3.utils import DeleteSourceObjectSubscriber\nfrom awscli.customizations.s3.transferconfig import RuntimeConfig\n'
# file: test_fileinfobuilder.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_fileinfobuilder.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_fileinfobuilder.py | grep import
# output: b'from awscli.testutils import mock \nfrom awscli.testutils import unittest\nfrom awscli.customizations.s3.filegenerator import FileStat\nfrom awscli.customizations.s3.fileinfo import FileInfo\nfrom awscli.customizations.s3.fileinfobuilder import FileInfoBuilder\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/__init__.py | grep import
# output: b'import os\nfrom awscli.compat import six\n'
# file: test_fileinfo.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_fileinfo.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_fileinfo.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.s3.fileinfo import FileInfo\n'
# file: test_copy_params.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_copy_params.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_copy_params.py | grep import
# output: b'import os\nimport sys\nimport re\nimport copy\nfrom awscli.testutils import BaseAWSCommandParamsTest\n    from StringIO import StringIO\n    import io\n'
# file: test_filters.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_filters.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_filters.py | grep import
# output: b'import os\nfrom awscli.testutils import unittest\nimport platform\nfrom awscli.customizations.s3.filegenerator import FileStat\nfrom awscli.customizations.s3.filters import Filter, create_filter\n'
# file: test_comparator.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_comparator.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_comparator.py | grep import
# output: b'import datetime\nimport unittest\nfrom awscli.testutils import mock\nfrom awscli.customizations.s3.comparator import Comparator\nfrom awscli.customizations.s3.filegenerator import FileStat\n'
# file: test_s3.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_s3.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_s3.py | grep import
# output: b'from awscli.testutils import mock, unittest, BaseAWSCommandParamsTest\nfrom awscli.customizations.s3.s3 import awscli_initialize, add_s3\n'
# file: test_fileformat.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_fileformat.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/s3/test_fileformat.py | grep import
# output: b'import os\nimport unittest\nfrom awscli.customizations.s3.fileformat import FileFormat\n'
# file: test_command.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_command.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_command.py | grep import
# output: b'from awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nimport argparse\nfrom awscli.customizations.emr.command import Command\n'
# file: test_describe_cluster.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_describe_cluster.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_describe_cluster.py | grep import
# output: b'import json\nfrom awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_create_cluster_release_label.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_cluster_release_label.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_cluster_release_label.py | grep import
# output: b'import copy\nimport os\nfrom botocore.compat import json\nfrom botocore.compat import OrderedDict\nfrom tests.unit.customizations.emr import test_constants as \\\nfrom tests.unit.customizations.emr import test_constants_instance_fleets as \\\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom awscli.testutils import mock\n'
# file: test_add_tags.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_add_tags.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_add_tags.py | grep import
# output: b'from tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_disable_hbase_backup.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_disable_hbase_backup.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_disable_hbase_backup.py | grep import
# output: b'from awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom copy import deepcopy\n'
# file: test_add_instance_groups.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_add_instance_groups.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_add_instance_groups.py | grep import
# output: b'from tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom tests.unit.customizations.emr import test_constants as \\\nimport json\nfrom awscli.testutils import mock\n'
# file: test_list_clusters.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_list_clusters.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_list_clusters.py | grep import
# output: b'from tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom datetime import datetime\nfrom time import mktime\n'
# file: test_create_cluster_ami_version.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_cluster_ami_version.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_cluster_ami_version.py | grep import
# output: b'from tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom tests.unit.customizations.emr import test_constants as \\\nfrom tests.unit.customizations.emr import test_constants_instance_fleets as \\\nfrom awscli.testutils import mock\nimport copy\nimport os\nimport json\n'
# file: test_schedule_hbase_backup.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_schedule_hbase_backup.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_schedule_hbase_backup.py | grep import
# output: b'from awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom copy import deepcopy\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/__init__.py | grep import
# output: b'from awscli.customizations.emr import exceptions\nfrom awscli.customizations.emr.configutils import ConfigWriter\nfrom awscli.customizations.preview import mark_as_preview\nfrom awscli.testutils import BaseAWSCommandParamsTest\nfrom awscli.testutils import mock\n'
# file: test_get_service_principal.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_get_service_principal.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_get_service_principal.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.emr.createdefaultroles import get_service_principal\nfrom awscli.customizations.emr.exceptions import \\\n'
# file: test_restore_from_hbase_backup.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_restore_from_hbase_backup.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_restore_from_hbase_backup.py | grep import
# output: b'from awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom copy import deepcopy\n'
# file: test_modify_cluster_attributes.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_modify_cluster_attributes.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_modify_cluster_attributes.py | grep import
# output: b'from tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_sshutils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_sshutils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_sshutils.py | grep import
# output: b'from awscli.customizations.emr import sshutils\nfrom awscli.customizations.emr import exceptions\nfrom awscli.testutils import mock, unittest\n'
# file: test_constants_instance_fleets.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_constants_instance_fleets.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_constants_instance_fleets.py | grep import
# output: b''
# file: test_create_default_role.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_default_role.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_default_role.py | grep import
# output: b'from botocore.compat import json\nfrom botocore.awsrequest import AWSResponse\nfrom botocore.exceptions import ClientError\nimport awscli.customizations.emr.emrutils as emrutils\nimport awscli.customizations.emr.createdefaultroles as createdefaultroles\nfrom awscli.testutils import mock, unittest\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_assume_role_policy.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_assume_role_policy.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_assume_role_policy.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.emr.createdefaultroles import assume_role_policy\n'
# file: test_terminate_clusters.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_terminate_clusters.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_terminate_clusters.py | grep import
# output: b'from tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_config.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_config.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_config.py | grep import
# output: b'from awscli.testutils import mock\nfrom awscli.customizations.emr.createcluster import CreateCluster\nfrom awscli.customizations.emr.exceptions import InvalidBooleanConfigError\nfrom awscli.customizations.emr.ssh import Get\nfrom awscli.customizations.emr.ssh import Put\nfrom awscli.customizations.emr.ssh import SSH\nfrom awscli.customizations.emr.ssh import Socks\nfrom awscli.testutils import BaseAWSHelpOutputTest\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_install_applications.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_install_applications.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_install_applications.py | grep import
# output: b'import json\nfrom awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_emrfs_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_emrfs_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_emrfs_utils.py | grep import
# output: b'import copy\nimport os\nimport json\nfrom awscli.customizations.emr.emrfsutils import CONSISTENT_OPTION_NAME\nfrom awscli.customizations.emr.emrfsutils import CSE_CUSTOM_OPTION_NAME\nfrom awscli.customizations.emr.emrfsutils import CSE_KMS_OPTION_NAME\nfrom awscli.customizations.emr.emrfsutils import CSE_OPTION_NAME\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_emr_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_emr_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_emr_utils.py | grep import
# output: b'from awscli.customizations.emr.emrutils import which\n'
# file: test_constants.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_constants.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_constants.py | grep import
# output: b''
# file: test_create_hbase_backup.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_hbase_backup.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_create_hbase_backup.py | grep import
# output: b'from awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\nfrom copy import deepcopy\n'
# file: test_add_steps.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_add_steps.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/emr/test_add_steps.py | grep import
# output: b'import os\nimport copy\nfrom awscli.testutils import mock\nfrom tests.unit.customizations.emr import EMRBaseAWSCommandParamsTest as \\\n'
# file: test_getstatus.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/test_getstatus.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/test_getstatus.py | grep import
# output: b'from awscli.compat import six\nfrom awscli.testutils import mock, unittest\nfrom awscli.customizations.configservice.getstatus import GetStatusCommand\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/__init__.py | grep import
# output: b''
# file: test_putconfigurationrecorder.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/test_putconfigurationrecorder.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/test_putconfigurationrecorder.py | grep import
# output: b'from awscli.clidriver import create_clidriver\nfrom awscli.arguments import CLIArgument\nfrom awscli.testutils import unittest\nfrom awscli.customizations.configservice.putconfigurationrecorder import \\\n'
# file: test_subscribe.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/test_subscribe.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configservice/test_subscribe.py | grep import
# output: b'import botocore.session\nfrom botocore.exceptions import ClientError\nfrom awscli.testutils import mock, unittest\nfrom awscli.compat import StringIO\nfrom awscli.customizations.configservice.subscribe import SubscribeCommand, \\\n'
# file: test_opsworks.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_opsworks.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_opsworks.py | grep import
# output: b'import argparse\nimport datetime\nimport json\nfrom botocore.exceptions import ClientError\nfrom awscli.customizations import opsworks\nfrom awscli.testutils import mock, unittest\n                "import": False,\n                "import": False,\n'
# file: test_list.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_list.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_list.py | grep import
# output: b'from argparse import Namespace\nfrom awscli.testutils import mock, unittest\nfrom awscli.compat import six\nfrom awscli.customizations.configure.list import ConfigureListCommand\nfrom . import FakeSession\n'
# file: test_writer.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_writer.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_writer.py | grep import
# output: b'import os\nimport tempfile\nimport shutil\nfrom awscli.customizations.configure.writer import ConfigFileWriter\nfrom awscli.testutils import unittest, skip_if_windows\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/__init__.py | grep import
# output: b'from botocore.exceptions import ProfileNotFound\n'
# file: test_addmodel.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_addmodel.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_addmodel.py | grep import
# output: b'import json\nimport os\nfrom botocore.session import get_session\nfrom botocore.loaders import Loader\nfrom awscli.customizations.configure.addmodel import get_model_location\nfrom awscli.testutils import unittest, FileCreator\n'
# file: test_configure.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_configure.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_configure.py | grep import
# output: b'import os\nfrom awscli.customizations.configure import configure, ConfigValue, NOT_SET\nfrom awscli.customizations.configure import profile_to_section\nfrom awscli.testutils import mock, unittest\nfrom awscli.compat import six\nfrom . import FakeSession\n'
# file: test_set.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_set.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_set.py | grep import
# output: b'import os\nfrom awscli.customizations.configure.set import ConfigureSetCommand\nfrom awscli.testutils import mock, unittest\nfrom . import FakeSession\n'
# file: test_get.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_get.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/configure/test_get.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.configure.get import ConfigureGetCommand\nfrom awscli.compat import six\nfrom . import FakeSession\n'
# file: test_cliinputjson.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_cliinputjson.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_cliinputjson.py | grep import
# output: b'import os\nimport shutil\nimport tempfile\nfrom awscli.testutils import mock, unittest\nfrom awscli.argprocess import ParamError\nfrom awscli.customizations.cliinputjson import CliInputJSONArgument\n'
# file: test_paginate.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_paginate.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_paginate.py | grep import
# output: b'from awscli.testutils import mock, unittest\nfrom botocore.exceptions import DataNotFoundError, PaginationError\nfrom botocore.model import OperationModel\nfrom awscli.help import OperationHelpCommand, OperationDocumentEventHandler\nfrom awscli.customizations import paginate\n'
# file: test_s3errormsg.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_s3errormsg.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_s3errormsg.py | grep import
# output: b'import copy\nfrom awscli.testutils import unittest\nfrom awscli.customizations import s3errormsg\n'
# file: test_generatecliskeleton.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_generatecliskeleton.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_generatecliskeleton.py | grep import
# output: b'from awscli.compat import six\nfrom botocore.model import DenormalizedStructureBuilder\nfrom awscli.testutils import mock, unittest\nfrom awscli.customizations.generatecliskeleton import \\\n'
# file: test_dynamodb.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_dynamodb.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_dynamodb.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.dynamodb import parse_last_evaluated_key_binary\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/__init__.py | grep import
# output: b''
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/__init__.py | grep import
# output: b''
# file: test_filehelpers.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_filehelpers.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_filehelpers.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.ecs.exceptions import MissingPropertyError\nfrom awscli.customizations.ecs.filehelpers import (APP_PREFIX,\n'
# file: test_codedeployer.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_codedeployer.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_codedeployer.py | grep import
# output: b'import hashlib\nimport json\nfrom botocore import compat\nfrom awscli.testutils import capture_output, mock, unittest\nfrom awscli.customizations.ecs.deploy import CodeDeployer, MAX_WAIT_MIN\nfrom awscli.customizations.ecs.exceptions import MissingPropertyError\n'
# file: test_ecsclient.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_ecsclient.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_ecsclient.py | grep import
# output: b'from argparse import Namespace\nfrom botocore import config\nfrom awscli.testutils import capture_output, mock, unittest\nfrom awscli.customizations.ecs.deploy import ECSClient, ECSDeploy\n'
# file: test_codedeployvalidator.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_codedeployvalidator.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_codedeployvalidator.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.customizations.ecs.deploy import (CodeDeployValidator,\nfrom awscli.customizations.ecs.exceptions import (InvalidPlatformError,\n'
# file: test_executecommand_startsession.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_executecommand_startsession.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/ecs/test_executecommand_startsession.py | grep import
# output: b'import botocore.session\nimport json\nimport errno\nfrom awscli.testutils import mock, unittest\nfrom awscli.customizations.ecs import executecommand\n'
# file: test_cloudwatch.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_cloudwatch.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_cloudwatch.py | grep import
# output: b'import decimal\nfrom awscli.testutils import mock, unittest\nfrom awscli.customizations import putmetricdata\n'
# file: test_getlog.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/gamelift/test_getlog.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/gamelift/test_getlog.py | grep import
# output: b'from argparse import Namespace\nimport os\nfrom botocore.session import get_session\nfrom awscli.compat import six\nfrom awscli.testutils import unittest, mock, FileCreator\nfrom awscli.customizations.gamelift.getlog import GetGameSessionLogCommand\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/gamelift/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/gamelift/__init__.py | grep import
# output: b'from awscli.testutils import unittest\nfrom awscli.testutils import mock\nfrom awscli.customizations.gamelift import register_gamelift_commands\nfrom awscli.customizations.gamelift import inject_commands\nfrom awscli.customizations.gamelift.uploadbuild import UploadBuildCommand\nfrom awscli.customizations.gamelift.getlog import GetGameSessionLogCommand\n'
# file: test_uploadbuild.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/gamelift/test_uploadbuild.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/gamelift/test_uploadbuild.py | grep import
# output: b'from argparse import Namespace\nimport contextlib\nimport os\nimport zipfile\nfrom botocore.session import get_session\nfrom botocore.exceptions import ClientError\nfrom awscli.compat import six\nfrom awscli.testutils import unittest, mock, FileCreator\nfrom awscli.customizations.gamelift.uploadbuild import UploadBuildCommand\nfrom awscli.customizations.gamelift.uploadbuild import zip_directory\nfrom awscli.customizations.gamelift.uploadbuild import validate_directory\n'
# file: test_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_utils.py | grep import
# output: b'from awscli.customizations.cloudtrail import utils\nfrom awscli.testutils import mock, unittest\n'
# file: test_validation.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_validation.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_validation.py | grep import
# output: b'import binascii\nimport base64\nimport hashlib\nimport json\nimport gzip\nfrom datetime import datetime, timedelta\nfrom dateutil import parser, tz\nimport rsa\nfrom argparse import Namespace\nfrom awscli.compat import six\nfrom awscli.testutils import BaseAWSCommandParamsTest\nfrom awscli.customizations.cloudtrail.validation import DigestError, \\\nfrom botocore.exceptions import ClientError\nfrom awscli.testutils import mock, unittest\nfrom awscli.schema import ParameterRequiredError\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/__init__.py | grep import
# output: b''
# file: test_subscribe.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_subscribe.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_subscribe.py | grep import
# output: b'import json\nfrom botocore.client import ClientError\nfrom botocore.session import Session\nfrom tests.unit.test_clidriver import FakeSession\nfrom awscli.compat import six\nfrom awscli.customizations.cloudtrail.subscribe import CloudTrailError, CloudTrailSubscribe\nfrom awscli.testutils import BaseAWSCommandParamsTest\nfrom awscli.testutils import mock, unittest, temporary_file\n'
# file: test_commands.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_commands.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/cloudtrail/test_commands.py | grep import
# output: b'from awscli.testutils import mock, unittest\nfrom awscli.customizations import cloudtrail\n'
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/__init__.py | grep import
# output: b''
# file: test_update_kubeconfig.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/test_update_kubeconfig.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/test_update_kubeconfig.py | grep import
# output: b'import glob\nimport os\nimport tempfile\nimport shutil\nimport sys\nimport botocore\nfrom botocore.compat import OrderedDict\nfrom awscli.testutils import mock, unittest\nfrom awscli.customizations.utils import uni_print\nimport awscli.customizations.eks.kubeconfig as kubeconfig\nfrom awscli.customizations.eks.update_kubeconfig import (KubeconfigSelector,\nfrom awscli.customizations.eks.exceptions import (EKSError,\nfrom awscli.customizations.eks.ordered_yaml import ordered_yaml_load\nfrom tests.functional.eks.test_util import get_testdata\nfrom tests.functional.eks.test_util import (describe_cluster_response,\n'
# file: test_get_token.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/test_get_token.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/test_get_token.py | grep import
# output: b'import base64\nimport botocore\nimport json\nfrom datetime import datetime\nfrom awscli.testutils import mock, unittest, capture_output\nfrom awscli.customizations.eks.get_token import (\n'
# file: test_kubeconfig.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/test_kubeconfig.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/eks/test_kubeconfig.py | grep import
# output: b'import glob\nimport os\nimport tempfile\nimport shutil\nfrom botocore.compat import OrderedDict\nfrom awscli.testutils import mock, unittest, skip_if_windows\nfrom awscli.customizations.utils import uni_print\nfrom awscli.customizations.eks.kubeconfig import (KubeconfigError,\nfrom awscli.customizations.eks.exceptions import EKSError\nfrom awscli.customizations.eks.ordered_yaml import ordered_yaml_load\nfrom tests.functional.eks.test_util import get_testdata\n'
# file: test_cloudsearchdomain.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_cloudsearchdomain.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/test_cloudsearchdomain.py | grep import
# output: b'from awscli.testutils import mock, unittest\nfrom awscli.testutils import BaseAWSCommandParamsTest\nfrom awscli.help import PagingHelpRenderer\nfrom awscli.customizations.cloudsearchdomain import validate_endpoint_url\n'
# file: test_systems.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/codedeploy/test_systems.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/codedeploy/test_systems.py | grep import
# output: b'import subprocess\nfrom argparse import Namespace\nfrom awscli.customizations.codedeploy.systems import Windows, Ubuntu, RHEL\nfrom awscli.testutils import mock, unittest\n'
# file: test_utils.py /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/codedeploy/test_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/tests/unit/customizations/codedeploy/test_utils.py | grep import
# ...
# file: arguments.py /Users/dougchang/Downloads/aws-cli-develop/awscli/arguments.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/arguments.py | grep import
# output: b'import logging\nfrom botocore import xform_name\nfrom botocore.hooks import first_non_none_response\nfrom awscli.argprocess import unpack_cli_arg\nfrom awscli.schema import SchemaTransformer\nfrom botocore import model\n'
# file: testutils.py /Users/dougchang/Downloads/aws-cli-develop/awscli/testutils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/testutils.py | grep import
# output: b'CLI unit/integration tests.  This module should not be imported by\nimport os\nimport sys\nimport copy\nimport shutil\nimport time\nimport json\nimport logging\nimport tempfile\nimport platform\nimport contextlib\nimport string\nimport binascii\nfrom pprint import pformat\nfrom subprocess import Popen, PIPE\nfrom unittest import mock\nfrom awscli.compat import StringIO\nfrom awscli.compat import six\nfrom botocore.session import Session\nfrom botocore.exceptions import ClientError\nfrom botocore.exceptions import WaiterError\nimport botocore.loaders\nfrom botocore.awsrequest import AWSResponse\nimport awscli.clidriver\nfrom awscli.plugin import load_plugins\nfrom awscli.clidriver import CLIDriver\nfrom awscli import EnvironmentVariables\nimport unittest\n    import awscli\n        # awscli/__init__.py injects AWS_DATA_PATH at import time\n'
# file: argprocess.py /Users/dougchang/Downloads/aws-cli-develop/awscli/argprocess.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/argprocess.py | grep import
# output: b'import os\nimport logging\nfrom awscli.compat import six\nfrom botocore.compat import OrderedDict, json\nfrom awscli import SCALAR_TYPES, COMPLEX_TYPES\nfrom awscli import shorthand\nfrom awscli.utils import (\nfrom botocore.utils import is_json_value_header\n'
# file: handlers.py /Users/dougchang/Downloads/aws-cli-develop/awscli/handlers.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/handlers.py | grep import
# output: b'from awscli.argprocess import ParamShorthandParser\nfrom awscli.paramfile import register_uri_param_handler\nfrom awscli.customizations import datapipeline\nfrom awscli.customizations.addexamples import add_examples\nfrom awscli.customizations.argrename import register_arg_renames\nfrom awscli.customizations.assumerole import register_assume_role_provider\nfrom awscli.customizations.awslambda import register_lambda_create_function\nfrom awscli.customizations.cliinputjson import register_cli_input_json\nfrom awscli.customizations.cloudformation import initialize as cloudformation_init\nfrom awscli.customizations.cloudfront import register as register_cloudfront\nfrom awscli.customizations.cloudsearch import initialize as cloudsearch_init\nfrom awscli.customizations.cloudsearchdomain import register_cloudsearchdomain\nfrom awscli.customizations.cloudtrail import initialize as cloudtrail_init\nfrom awscli.customizations.codeartifact import register_codeartifact_commands\nfrom awscli.customizations.codecommit import initialize as codecommit_init\nfrom awscli.customizations.codedeploy.codedeploy import initialize as \\\nfrom awscli.customizations.configservice.getstatus import register_get_status\nfrom awscli.customizations.configservice.putconfigurationrecorder import \\\nfrom awscli.customizations.configservice.rename_cmd import \\\nfrom awscli.customizations.configservice.subscribe import register_subscribe\nfrom awscli.customizations.configure.configure import register_configure_cmd\nfrom awscli.customizations.history import register_history_mode\nfrom awscli.customizations.history import register_history_commands\nfrom awscli.customizations.ec2.addcount import register_count_events\nfrom awscli.customizations.ec2.bundleinstance import register_bundleinstance\nfrom awscli.customizations.ec2.decryptpassword import ec2_add_priv_launch_key\nfrom awscli.customizations.ec2.protocolarg import register_protocol_args\nfrom awscli.customizations.ec2.runinstances import register_runinstances\nfrom awscli.customizations.ec2.secgroupsimplify import register_secgroup\nfrom awscli.customizations.ec2.paginate import register_ec2_page_size_injector\nfrom awscli.customizations.ecr import register_ecr_commands\nfrom awscli.customizations.ecr_public import register_ecr_public_commands\nfrom awscli.customizations.emr.emr import emr_initialize\nfrom awscli.customizations.emrcontainers import \\\nfrom awscli.customizations.eks import initialize as eks_initialize\nfrom awscli.customizations.ecs import initialize as ecs_initialize\nfrom awscli.customizations.gamelift import register_gamelift_commands\nfrom awscli.customizations.generatecliskeleton import \\\nfrom awscli.customizations.globalargs import register_parse_global_args\nfrom awscli.customizations.iamvirtmfa import IAMVMFAWrapper\nfrom awscli.customizations.iot import register_create_keys_and_cert_arguments\nfrom awscli.customizations.iot import register_create_keys_from_csr_arguments\nfrom awscli.customizations.iot_data import register_custom_endpoint_note\nfrom awscli.customizations.kms import register_fix_kms_create_grant_docs\nfrom awscli.customizations.dlm.dlm import dlm_initialize\nfrom awscli.customizations.opsworks import initialize as opsworks_init\nfrom awscli.customizations.paginate import register_pagination\nfrom awscli.customizations.preview import register_preview_commands\nfrom awscli.customizations.putmetricdata import register_put_metric_data\nfrom awscli.customizations.rds import register_rds_modify_split\nfrom awscli.customizations.rds import register_add_generate_db_auth_token\nfrom awscli.customizations.rekognition import register_rekognition_detect_labels\nfrom awscli.customizations.removals import register_removals\nfrom awscli.customizations.route53 import register_create_hosted_zone_doc_fix\nfrom awscli.customizations.s3.s3 import s3_plugin_initialize\nfrom awscli.customizations.s3errormsg import register_s3_error_msg\nfrom awscli.customizations.scalarparse ...
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/awscli/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/__init__.py | grep import
# output: b'import os\n'
# file: completer.py /Users/dougchang/Downloads/aws-cli-develop/awscli/completer.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/completer.py | grep import
# output: b'import awscli.clidriver\nimport sys\nimport logging\nimport copy\n'
# file: utils.py /Users/dougchang/Downloads/aws-cli-develop/awscli/utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/utils.py | grep import
# output: b'import csv\nimport signal\nimport datetime\nimport contextlib\nimport os\nimport sys\nimport subprocess\nfrom awscli.compat import six\nfrom awscli.compat import get_binary_stdout\nfrom awscli.compat import get_popen_kwargs_for_pager_cmd\n'
# file: text.py /Users/dougchang/Downloads/aws-cli-develop/awscli/text.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/text.py | grep import
# output: b'from awscli.compat import six\n'
# file: plugin.py /Users/dougchang/Downloads/aws-cli-develop/awscli/plugin.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/plugin.py | grep import
# output: b'import logging\nfrom botocore.hooks import HierarchicalEmitter\n    :param plugin_mapping: A dict of plugin name to import path,\n    modules = _import_plugins(plugin_mapping)\ndef _import_plugins(plugin_names):\n            plugins.append(__import__(path))\n            module = __import__(path, fromlist=[module])\n'
# file: paramfile.py /Users/dougchang/Downloads/aws-cli-develop/awscli/paramfile.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/paramfile.py | grep import
# output: b'import logging\nimport os\nimport copy\nfrom botocore.awsrequest import AWSRequest\nfrom botocore.httpsession import URLLib3Session\nfrom botocore.exceptions import ProfileNotFound\nfrom awscli.compat import six\nfrom awscli.compat import compat_open\nfrom awscli.argprocess import ParamError\n'
# file: table.py /Users/dougchang/Downloads/aws-cli-develop/awscli/table.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/table.py | grep import
# output: b'import sys\nimport struct\nimport unicodedata\nimport colorama\nfrom awscli.utils import is_a_tty\nfrom awscli.compat import six\n        from termios import TIOCGWINSZ\n        from fcntl import ioctl\n'
# file: clidocs.py /Users/dougchang/Downloads/aws-cli-develop/awscli/clidocs.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/clidocs.py | grep import
# output: b'import logging\nimport os\nfrom botocore import xform_name\nfrom botocore.model import StringShape\nfrom botocore.utils import is_json_value_header\nfrom awscli import SCALAR_TYPES\nfrom awscli.argprocess import ParamShorthandDocGen\nfrom awscli.bcdoc.docevents import DOC_EVENTS\nfrom awscli.topictags import TopicTagDB\nfrom awscli.utils import (\n'
# file: topictags.py /Users/dougchang/Downloads/aws-cli-develop/awscli/topictags.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/topictags.py | grep import
# output: b'import os\nimport json\nimport docutils.core\n'
# file: docevents.py /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/docevents.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/docevents.py | grep import
# output: b''
# file: style.py /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/style.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/style.py | grep import
# output: b'import logging\n    def start_important(self, attrs=None):\n    def end_important(self):\n'
# file: docstringparser.py /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/docstringparser.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/docstringparser.py | grep import
# output: b'from botocore.compat import six\n'
# file: textwriter.py /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/textwriter.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/textwriter.py | grep import
# output: b"import os\nimport re\nimport textwrap\nfrom docutils import nodes, writers\n    visit_important = _visit_admonition\n    depart_important = _make_depart_admonition('important')\n"
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/__init__.py | grep import
# output: b''
# file: restdoc.py /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/restdoc.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/bcdoc/restdoc.py | grep import
# output: b'import logging\nfrom botocore.compat import OrderedDict\nfrom awscli.bcdoc.docstringparser import DocStringParser\nfrom awscli.bcdoc.style import ReSTStyle\n'
# file: argparser.py /Users/dougchang/Downloads/aws-cli-develop/awscli/argparser.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/argparser.py | grep import
# output: b'import argparse\nimport sys\nfrom awscli.compat import six\nfrom difflib import get_close_matches\n'
# file: help.py /Users/dougchang/Downloads/aws-cli-develop/awscli/help.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/help.py | grep import
# output: b'import logging\nimport os\nimport sys\nimport platform\nimport shlex\nfrom subprocess import Popen, PIPE\nfrom docutils.core import publish_string\nfrom docutils.writers import manpage\nfrom awscli.clidocs import ProviderDocumentEventHandler\nfrom awscli.clidocs import ServiceDocumentEventHandler\nfrom awscli.clidocs import OperationDocumentEventHandler\nfrom awscli.clidocs import TopicListerDocumentEventHandler\nfrom awscli.clidocs import TopicDocumentEventHandler\nfrom awscli.bcdoc import docevents\nfrom awscli.bcdoc.restdoc import ReSTDocument\nfrom awscli.bcdoc.textwriter import TextWriter\nfrom awscli.argprocess import ParamShorthandParser\nfrom awscli.argparser import ArgTableArgParser\nfrom awscli.topictags import TopicTagDB\nfrom awscli.utils import ignore_ctrl_c\n'
# file: errorhandler.py /Users/dougchang/Downloads/aws-cli-develop/awscli/errorhandler.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/errorhandler.py | grep import
# output: b'import logging\n'
# file: commands.py /Users/dougchang/Downloads/aws-cli-develop/awscli/commands.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/commands.py | grep import
# output: b''
# file: __main__.py /Users/dougchang/Downloads/aws-cli-develop/awscli/__main__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/__main__.py | grep import
# output: b'import sys\nfrom awscli.clidriver import main\n'
# file: schema.py /Users/dougchang/Downloads/aws-cli-develop/awscli/schema.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/awscli/schema.py | grep import
# output: b'from collections import defaultdict\n'
# file: setup.py /Users/dougchang/Downloads/aws-cli-develop/setup.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/setup.py | grep import
# output: b'import codecs\nimport os.path\nimport re\nimport sys\nfrom setuptools import setup, find_packages\n    import py2exe\n'
# file: benchmark_utils.py /Users/dougchang/Downloads/aws-cli-develop/scripts/performance/benchmark_utils.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/scripts/performance/benchmark_utils.py | grep import
# output: b'import s3transfer\nimport os\nimport subprocess\nimport uuid\nimport shutil\nimport argparse\nimport tempfile\n'
# file: bootstrapdocs.py /Users/dougchang/Downloads/aws-cli-develop/doc/source/bootstrapdocs.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/doc/source/bootstrapdocs.py | grep import
# output: b'import json\nimport os\nimport subprocess\nimport sys\n'
# file: conf.py /Users/dougchang/Downloads/aws-cli-develop/doc/source/conf.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/doc/source/conf.py | grep import
# output: b"import sys, os\nimport bootstrapdocs\n             ('reference/importexport/index', 'aws-importexport',\n"
# file: __init__.py /Users/dougchang/Downloads/aws-cli-develop/doc/source/guzzle_sphinx_theme/__init__.py
# cmd: cat /Users/dougchang/Downloads/aws-cli-develop/doc/source/guzzle_sphinx_theme/__init__.py | grep import
# output: b'import os\nimport xml.etree.ElementTree as ET\nfrom docutils import nodes\nfrom sphinx.locale import admonitionlabels\nfrom sphinx.writers.html import HTMLTranslator as SphinxHTMLTranslator\nfrom pygments.style import Style\nfrom pygments.token import Keyword, Name, Comment, String, Error, \\\n'
